# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
players=pd.read_csv("playerAttributes.csv")
players.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ### Removing unimportant attributes:

# %%
players.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
players.drop(['Unnamed: 0','ID','Name','Age','Photo','Nationality','Flag','Potential','Club','Club Logo','Value','Wage','Special',
       'Preferred Foot', 'International Reputation','Weak Foot',
       'Skill Moves','Work Rate','Body Type','Real Face','Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
       'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
       'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
       'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Release Clause'],axis=1,inplace=True)
players.head()
# Out:
#    Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 0       94       RF      84.0       95.0             70.0          90.0
# 1       94       ST      84.0       94.0             89.0          81.0
# 2       92       LW      79.0       87.0             62.0          84.0
# 3       91       GK      17.0       13.0             21.0          50.0
# 4       91      RCM      93.0       82.0             55.0          92.0
#
#    Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 0     86.0       97.0   93.0        94.0  ...       75.0       96.0     33.0
# 1     87.0       88.0   81.0        76.0  ...       85.0       95.0     28.0
# 2     84.0       96.0   88.0        87.0  ...       81.0       94.0     27.0
# 3     13.0       18.0   21.0        19.0  ...       40.0       68.0     15.0
# 4     82.0       86.0   85.0        83.0  ...       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
players['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %% [markdown]
# ### Striker analysis (ST, LS, RS)

# %%
strikers=players.loc[(players['Position']=='ST')|(players['Position']=='LS')|(players['Position']=='RS')].copy()
strikers.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 1        94       ST      84.0       94.0             89.0          81.0
# 7        91       RS      77.0       93.0             77.0          82.0
# 10       90       ST      62.0       91.0             85.0          83.0
# 16       89       ST      75.0       94.0             85.0          80.0
# 21       89       LS      70.0       89.0             89.0          78.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 1      87.0       88.0   81.0        76.0  ...       85.0       95.0     28.0
# 7      88.0       87.0   86.0        84.0  ...       85.0       85.0     62.0
# 10     89.0       85.0   77.0        86.0  ...       88.0       86.0     34.0
# 16     84.0       80.0   78.0        68.0  ...       90.0       89.0     56.0
# 21     90.0       80.0   77.0        76.0  ...       85.0       82.0     52.0
#
# ...

# %%
strikers.drop(['Position'],axis=1,inplace=True)
strikers.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 1        94      84.0       94.0             89.0          81.0     87.0
# 7        91      77.0       93.0             77.0          82.0     88.0
# 10       90      62.0       91.0             85.0          83.0     89.0
# 16       89      75.0       94.0             85.0          80.0     84.0
# 21       89      70.0       89.0             89.0          78.0     90.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 1        88.0   81.0        76.0         77.0  ...       85.0       95.0
# 7        87.0   86.0        84.0         64.0  ...       85.0       85.0
# 10       85.0   77.0        86.0         65.0  ...       88.0       86.0
# 16       80.0   78.0        68.0         82.0  ...       90.0       89.0
# 21       80.0   77.0        76.0         52.0  ...       85.0       82.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(strikers)
# Out:
# 2562

# %%
strikers.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.614259   0.902016         0.664870      0.820211
# Crossing         0.614259  1.000000   0.460713         0.169418      0.690990
# Finishing        0.902016  0.460713   1.000000         0.656792      0.680063
# HeadingAccuracy  0.664870  0.169418   0.656792         1.000000      0.448334
# ShortPassing     0.820211  0.690990   0.680063         0.448334      1.000000
# Volleys          0.830210  0.544188   0.750602         0.569935      0.696938
# Dribbling        0.804175  0.660392   0.674334         0.283882      0.749859
# Curve            0.654706  0.658210   0.547244         0.266343      0.652045
# FKAccuracy       0.577493  0.633909   0.480608         0.237232      0.583882
# LongPassing      0.586801  0.715515   0.448200         0.222578      0.744361
# BallControl      0.901148  0.623467   0.787026         0.482502      0.806689
# ...

# %%
corr=strikers.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
strikers.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# Positioning        0.909207
# Finishing          0.902016
# BallControl        0.901148
# ShotPower          0.874362
# Reactions          0.869161
# Composure          0.831669
# Volleys            0.830210
# ShortPassing       0.820211
# Dribbling          0.804175
# LongShots          0.794537
# Vision             0.677674
# HeadingAccuracy    0.664870
# Curve              0.654706
# Crossing           0.614259
# Penalties          0.592026
# LongPassing        0.586801
# FKAccuracy         0.577493
# Aggression         0.521356
# Strength           0.459841
# Stamina            0.458522
# Interceptions      0.398569
# StandingTackle     0.358137
# Marking            0.333553
# Jumping            0.317552
# Agility            0.283607
# SlidingTackle      0.263553
# SprintSpeed        0.209845
# Acceleration       0.171982
# GKHandling         0.076662
# GKDiving           0.047834
# GKReflexes         0.038505
# GKKicking          0.037917
# ...

# %% [markdown]
# ### Forward Analysis (CF,RF,LF)

# %%
forwards=players.loc[(players['Position']=='CF')|(players['Position']=='RF')|(players['Position']=='LF')].copy()
forwards.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 0        94       RF      84.0       95.0             70.0          90.0
# 5        91       LF      81.0       84.0             61.0          89.0
# 15       89       LF      82.0       84.0             68.0          87.0
# 50       87       RF      77.0       86.0             35.0          82.0
# 76       86       LF      77.0       70.0             54.0          90.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 0      86.0       97.0   93.0        94.0  ...       75.0       96.0     33.0
# 5      80.0       95.0   83.0        79.0  ...       86.0       91.0     34.0
# 15     88.0       92.0   88.0        88.0  ...       86.0       84.0     23.0
# 50     70.0       91.0   82.0        79.0  ...       79.0       81.0     25.0
# 76     74.0       90.0   80.0        70.0  ...       71.0       89.0     67.0
#
# ...

# %%
forwards.drop(['Position'],axis=1,inplace=True)
forwards.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 0        94      84.0       95.0             70.0          90.0     86.0
# 5        91      81.0       84.0             61.0          89.0     80.0
# 15       89      82.0       84.0             68.0          87.0     88.0
# 50       87      77.0       86.0             35.0          82.0     70.0
# 76       86      77.0       70.0             54.0          90.0     74.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 0        97.0   93.0        94.0         87.0  ...       75.0       96.0
# 5        95.0   83.0        79.0         83.0  ...       86.0       91.0
# 15       92.0   88.0        88.0         75.0  ...       86.0       84.0
# 50       91.0   82.0        79.0         74.0  ...       79.0       81.0
# 76       90.0   80.0        70.0         85.0  ...       71.0       89.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(forwards)
# Out:
# 105

# %%
forwards.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.779054   0.889539         0.365663      0.911561
# Crossing         0.779054  1.000000   0.638982         0.193798      0.785245
# Finishing        0.889539  0.638982   1.000000         0.478531      0.742646
# HeadingAccuracy  0.365663  0.193798   0.478531         1.000000      0.280490
# ShortPassing     0.911561  0.785245   0.742646         0.280490      1.000000
# Volleys          0.782419  0.588533   0.732375         0.513479      0.665896
# Dribbling        0.906697  0.708180   0.748043         0.182920      0.842377
# Curve            0.782847  0.698432   0.675393         0.170222      0.728577
# FKAccuracy       0.755202  0.709909   0.676864         0.193340      0.725432
# LongPassing      0.755882  0.805415   0.588380         0.144995      0.822351
# BallControl      0.949432  0.768022   0.811481         0.299517      0.895407
# ...

# %%
corr=forwards.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
forwards.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# BallControl        0.949432
# Positioning        0.924688
# ShortPassing       0.911561
# Dribbling          0.906697
# Reactions          0.902817
# Finishing          0.889539
# LongShots          0.886758
# Composure          0.885845
# Vision             0.841613
# Curve              0.782847
# Volleys            0.782419
# Crossing           0.779054
# ShotPower          0.765289
# LongPassing        0.755882
# FKAccuracy         0.755202
# Penalties          0.646195
# Stamina            0.575458
# Agility            0.473020
# Acceleration       0.443023
# Aggression         0.437176
# StandingTackle     0.409049
# Marking            0.391985
# Interceptions      0.387887
# Balance            0.385350
# SlidingTackle      0.366755
# HeadingAccuracy    0.365663
# SprintSpeed        0.355678
# Strength           0.242984
# GKHandling         0.100301
# Jumping            0.060794
# GKReflexes         0.038789
# GKKicking          0.003900
# ...

# %% [markdown]
# ### Attacking Wingers Analysis (RW, LW)

# %%
attWingers=players.loc[(players['Position']=='RW')|(players['Position']=='LW')].copy()
attWingers.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 2        92       LW      79.0       87.0             62.0          84.0
# 29       88       LW      86.0       77.0             56.0          85.0
# 30       88       LW      75.0       79.0             55.0          89.0
# 32       88       LW      79.0       79.0             48.0          88.0
# 55       86       LW      83.0       81.0             72.0          79.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 2      84.0       96.0   88.0        87.0  ...       81.0       94.0     27.0
# 29     74.0       90.0   87.0        77.0  ...       61.0       83.0     51.0
# 30     65.0       94.0   88.0        76.0  ...       76.0       86.0     60.0
# 32     75.0       91.0   91.0        86.0  ...       70.0       85.0     55.0
# 55     85.0       88.0   82.0        68.0  ...       71.0       78.0     36.0
#
# ...

# %%
attWingers.drop(['Position'],axis=1,inplace=True)
attWingers.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 2        92      79.0       87.0             62.0          84.0     84.0
# 29       88      86.0       77.0             56.0          85.0     74.0
# 30       88      75.0       79.0             55.0          89.0     65.0
# 32       88      79.0       79.0             48.0          88.0     75.0
# 55       86      83.0       81.0             72.0          79.0     85.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 2        96.0   88.0        87.0         78.0  ...       81.0       94.0
# 29       90.0   87.0        77.0         78.0  ...       61.0       83.0
# 30       94.0   88.0        76.0         83.0  ...       76.0       86.0
# 32       91.0   91.0        86.0         83.0  ...       70.0       85.0
# 55       88.0   82.0        68.0         64.0  ...       71.0       78.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(attWingers)
# Out:
# 751

# %%
attWingers.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.772218   0.721336         0.339634      0.876960
# Crossing         0.772218  1.000000   0.443030         0.165851      0.771335
# Finishing        0.721336  0.443030   1.000000         0.415919      0.552386
# HeadingAccuracy  0.339634  0.165851   0.415919         1.000000      0.296330
# ShortPassing     0.876960  0.771335   0.552386         0.296330      1.000000
# Volleys          0.683128  0.523021   0.649652         0.376461      0.585637
# Dribbling        0.901025  0.703959   0.614436         0.204285      0.767150
# Curve            0.726345  0.669770   0.483196         0.125510      0.674797
# FKAccuracy       0.612269  0.620719   0.403629         0.168949      0.592683
# LongPassing      0.714137  0.733044   0.407042         0.197930      0.825573
# BallControl      0.917393  0.720856   0.614384         0.250924      0.829724
# ...

# %%
corr=attWingers.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
attWingers.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# BallControl        0.917393
# Dribbling          0.901025
# ShortPassing       0.876960
# Reactions          0.867029
# Positioning        0.847970
# Composure          0.826851
# Vision             0.821689
# LongShots          0.777837
# Crossing           0.772218
# Curve              0.726345
# Finishing          0.721336
# LongPassing        0.714137
# Volleys            0.683128
# ShotPower          0.669026
# FKAccuracy         0.612269
# Stamina            0.572834
# Agility            0.524012
# Acceleration       0.498415
# Penalties          0.471986
# SprintSpeed        0.438483
# Aggression         0.421691
# HeadingAccuracy    0.339634
# Interceptions      0.322210
# Balance            0.285002
# Strength           0.236754
# Marking            0.225742
# StandingTackle     0.216608
# Jumping            0.183944
# SlidingTackle      0.134487
# GKPositioning      0.107801
# GKKicking          0.058903
# GKDiving           0.039700
# ...

# %% [markdown]
# ### Attacking Midfielders Analysis (CAM, LAM, RAM)

# %%
attmid=players.loc[(players['Position']=='CAM')|(players['Position']=='RAM')|(players['Position']=='LAM')].copy()
attmid.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 17       89      CAM      82.0       90.0             84.0          83.0
# 28       88      LAM      90.0       83.0             62.0          89.0
# 31       88      CAM      88.0       80.0             52.0          91.0
# 61       86      CAM      72.0       87.0             77.0          86.0
# 66       86      CAM      79.0       87.0             82.0          83.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 17     87.0       88.0   84.0        78.0  ...       79.0       87.0     59.0
# 28     90.0       85.0   89.0        86.0  ...       81.0       87.0     52.0
# 31     77.0       84.0   86.0        87.0  ...       67.0       88.0     59.0
# 61     81.0       87.0   80.0        65.0  ...       72.0       87.0     60.0
# 66     84.0       75.0   81.0        59.0  ...       60.0       83.0     44.0
#
# ...

# %%
attmid.drop(['Position'],axis=1,inplace=True)
attmid.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 17       89      82.0       90.0             84.0          83.0     87.0
# 28       88      90.0       83.0             62.0          89.0     90.0
# 31       88      88.0       80.0             52.0          91.0     77.0
# 61       86      72.0       87.0             77.0          86.0     81.0
# 66       86      79.0       87.0             82.0          83.0     84.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 17       88.0   84.0        78.0         76.0  ...       79.0       87.0
# 28       85.0   89.0        86.0         83.0  ...       81.0       87.0
# 31       84.0   86.0        87.0         88.0  ...       67.0       88.0
# 61       87.0   80.0        65.0         75.0  ...       72.0       87.0
# 66       75.0   81.0        59.0         72.0  ...       60.0       83.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(attmid)
# Out:
# 1000

# %%
attmid.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.791225   0.804176         0.408668      0.854687
# Crossing         0.791225  1.000000   0.621036         0.265584      0.724603
# Finishing        0.804176  0.621036   1.000000         0.443680      0.594429
# HeadingAccuracy  0.408668  0.265584   0.443680         1.000000      0.316732
# ShortPassing     0.854687  0.724603   0.594429         0.316732      1.000000
# Volleys          0.745137  0.671090   0.679490         0.409321      0.620269
# Dribbling        0.872275  0.703042   0.702878         0.225416      0.701335
# Curve            0.718019  0.745320   0.558143         0.239988      0.639664
# FKAccuracy       0.679130  0.728001   0.547969         0.213602      0.619250
# LongPassing      0.725309  0.675411   0.469196         0.271756      0.843662
# BallControl      0.920842  0.750347   0.723682         0.325798      0.810693
# ...

# %%
corr=attmid.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
attmid.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# BallControl        0.920842
# Dribbling          0.872275
# Vision             0.865493
# Positioning        0.860432
# ShortPassing       0.854687
# Reactions          0.853099
# LongShots          0.815866
# Finishing          0.804176
# Composure          0.792721
# Crossing           0.791225
# Volleys            0.745137
# ShotPower          0.737138
# LongPassing        0.725309
# Curve              0.718019
# FKAccuracy         0.679130
# Penalties          0.642386
# Stamina            0.510222
# HeadingAccuracy    0.408668
# Agility            0.384450
# Interceptions      0.363919
# Aggression         0.354350
# Strength           0.348844
# StandingTackle     0.232734
# Marking            0.225903
# Acceleration       0.221526
# Jumping            0.185913
# SprintSpeed        0.185394
# Balance            0.101019
# SlidingTackle      0.089911
# GKReflexes         0.073721
# GKHandling         0.048554
# GKKicking          0.035808
# ...

# %% [markdown]
# ### Midfield Winger Analysis (LM,RM)

# %%
midWing=players.loc[(players['Position']=='LM')|(players['Position']=='RM')].copy()
midWing.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 25       88       RM      77.0       88.0             77.0          82.0
# 26       88       RM      78.0       90.0             59.0          82.0
# 33       88       LM      77.0       88.0             79.0          77.0
# 58       86       LM      73.0       84.0             62.0          79.0
# 65       86       LM      84.0       67.0             50.0          84.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 25     78.0       90.0   77.0        63.0  ...       70.0       86.0     34.0
# 26     73.0       89.0   83.0        60.0  ...       61.0       91.0     38.0
# 33     86.0       79.0   80.0        74.0  ...       76.0       86.0     27.0
# 58     71.0       87.0   74.0        64.0  ...       71.0       80.0     42.0
# 65     76.0       92.0   84.0        78.0  ...       77.0       84.0     45.0
#
# ...

# %%
midWing.drop(['Position'],axis=1,inplace=True)
midWing.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 25       88      77.0       88.0             77.0          82.0     78.0
# 26       88      78.0       90.0             59.0          82.0     73.0
# 33       88      77.0       88.0             79.0          77.0     86.0
# 58       86      73.0       84.0             62.0          79.0     71.0
# 65       86      84.0       67.0             50.0          84.0     76.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 25       90.0   77.0        63.0         73.0  ...       70.0       86.0
# 26       89.0   83.0        60.0         72.0  ...       61.0       91.0
# 33       79.0   80.0        74.0         64.0  ...       76.0       86.0
# 58       87.0   74.0        64.0         71.0  ...       71.0       80.0
# 65       92.0   84.0        78.0         68.0  ...       77.0       84.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(midWing)
# Out:
# 2219

# %%
midWing.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.783028   0.710382         0.396576      0.857644
# Crossing         0.783028  1.000000   0.472300         0.247121      0.722399
# Finishing        0.710382  0.472300   1.000000         0.362026      0.533509
# HeadingAccuracy  0.396576  0.247121   0.362026         1.000000      0.349314
# ShortPassing     0.857644  0.722399   0.533509         0.349314      1.000000
# Volleys          0.644104  0.498951   0.662919         0.363647      0.522413
# Dribbling        0.883403  0.659766   0.664506         0.243659      0.714092
# Curve            0.691659  0.662112   0.502867         0.218523      0.629737
# FKAccuracy       0.567360  0.563967   0.421255         0.153580      0.545613
# LongPassing      0.685261  0.662901   0.375150         0.268833      0.819190
# BallControl      0.914093  0.705080   0.668749         0.315478      0.796066
# ...

# %%
corr=midWing.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
midWing.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# BallControl        0.914093
# Dribbling          0.883403
# ShortPassing       0.857644
# Positioning        0.839741
# Reactions          0.839496
# Vision             0.822585
# Composure          0.810764
# Crossing           0.783028
# LongShots          0.760121
# Finishing          0.710382
# ShotPower          0.694465
# Curve              0.691659
# LongPassing        0.685261
# Volleys            0.644104
# FKAccuracy         0.567360
# Stamina            0.524337
# Penalties          0.504774
# Agility            0.471429
# Acceleration       0.419827
# HeadingAccuracy    0.396576
# SprintSpeed        0.393309
# Aggression         0.392341
# Interceptions      0.313532
# Jumping            0.267544
# Strength           0.263540
# Marking            0.250705
# Balance            0.217481
# StandingTackle     0.207447
# SlidingTackle      0.148062
# GKKicking          0.077396
# GKDiving           0.070712
# GKPositioning      0.052302
# ...

# %% [markdown]
# ### Center Midfield Analysis (CM,RCM,LCM)

# %%
cenMid=players.loc[(players['Position']=='CM')|(players['Position']=='RCM')|(players['Position']=='LCM')].copy()
cenMid.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 4        91      RCM      93.0       82.0             55.0          92.0
# 6        91      RCM      86.0       72.0             55.0          93.0
# 11       90      LCM      88.0       76.0             54.0          92.0
# 13       90      LCM      84.0       76.0             54.0          93.0
# 52       87      LCM      78.0       79.0             74.0          88.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 4      82.0       86.0   85.0        83.0  ...       79.0       88.0     68.0
# 6      76.0       90.0   85.0        78.0  ...       82.0       84.0     60.0
# 11     82.0       81.0   86.0        84.0  ...       73.0       85.0     72.0
# 13     82.0       89.0   82.0        77.0  ...       75.0       93.0     59.0
# 52     79.0       86.0   80.0        72.0  ...       70.0       84.0     75.0
#
# ...

# %%
cenMid.drop(['Position'],axis=1,inplace=True)
cenMid.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 4        91      93.0       82.0             55.0          92.0     82.0
# 6        91      86.0       72.0             55.0          93.0     76.0
# 11       90      88.0       76.0             54.0          92.0     82.0
# 13       90      84.0       76.0             54.0          93.0     82.0
# 52       87      78.0       79.0             74.0          88.0     79.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 4        86.0   85.0        83.0         91.0  ...       79.0       88.0
# 6        90.0   85.0        78.0         88.0  ...       82.0       84.0
# 11       81.0   86.0        84.0         93.0  ...       73.0       85.0
# 13       89.0   82.0        77.0         87.0  ...       75.0       93.0
# 52       86.0   80.0        72.0         83.0  ...       70.0       84.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(cenMid)
# Out:
# 2180

# %%
cenMid.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.745074   0.677655         0.445675      0.900168
# Crossing         0.745074  1.000000   0.641630         0.289633      0.677064
# Finishing        0.677655  0.641630   1.000000         0.278781      0.569981
# HeadingAccuracy  0.445675  0.289633   0.278781         1.000000      0.370569
# ShortPassing     0.900168  0.677064   0.569981         0.370569      1.000000
# Volleys          0.639495  0.681995   0.674739         0.306761      0.570970
# Dribbling        0.839227  0.715608   0.691805         0.256946      0.779092
# Curve            0.676624  0.762953   0.639959         0.170893      0.623193
# FKAccuracy       0.608923  0.701371   0.594974         0.175345      0.566049
# LongPassing      0.873657  0.678467   0.549119         0.373866      0.910205
# BallControl      0.919851  0.736318   0.665925         0.334895      0.866475
# ...

# %%
corr=cenMid.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
cenMid.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# BallControl        0.919851
# ShortPassing       0.900168
# LongPassing        0.873657
# Reactions          0.870867
# Vision             0.868832
# Dribbling          0.839227
# Composure          0.823537
# LongShots          0.779927
# Crossing           0.745074
# Positioning        0.743965
# ShotPower          0.740154
# Interceptions      0.682895
# Finishing          0.677655
# Curve              0.676624
# Volleys            0.639495
# StandingTackle     0.625811
# FKAccuracy         0.608923
# Marking            0.606619
# Penalties          0.579939
# Stamina            0.555604
# Aggression         0.497040
# SlidingTackle      0.491170
# HeadingAccuracy    0.445675
# Strength           0.429034
# Agility            0.353036
# Jumping            0.192124
# Acceleration       0.160196
# Balance            0.125843
# SprintSpeed        0.112629
# GKKicking          0.061952
# GKReflexes         0.057860
# GKHandling         0.049428
# ...

# %% [markdown]
# ### Defensive Midfielder Analysis (CDM,RDM,LDM)

# %%
defMid=players.loc[(players['Position']=='CDM')|(players['Position']=='RDM')|(players['Position']=='LDM')].copy()
defMid.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 14       89      LDM      68.0       65.0             54.0          86.0
# 20       89      CDM      62.0       67.0             68.0          89.0
# 27       88      CDM      52.0       59.0             76.0          85.0
# 45       87      RDM      80.0       73.0             73.0          86.0
# 72       86      CDM      80.0       60.0             60.0          89.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 14     56.0       79.0   49.0        49.0  ...       54.0       85.0     90.0
# 20     44.0       80.0   66.0        68.0  ...       60.0       90.0     90.0
# 27     53.0       69.0   59.0        74.0  ...       66.0       84.0     88.0
# 45     85.0       87.0   84.0        82.0  ...       81.0       87.0     66.0
# 72     72.0       86.0   86.0        92.0  ...       79.0       86.0     75.0
#
# ...

# %%
defMid.drop(['Position'],axis=1,inplace=True)
defMid.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 14       89      68.0       65.0             54.0          86.0     56.0
# 20       89      62.0       67.0             68.0          89.0     44.0
# 27       88      52.0       59.0             76.0          85.0     53.0
# 45       87      80.0       73.0             73.0          86.0     85.0
# 72       86      80.0       60.0             60.0          89.0     72.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 14       79.0   49.0        49.0         81.0  ...       54.0       85.0
# 20       80.0   66.0        68.0         82.0  ...       60.0       90.0
# 27       69.0   59.0        74.0         82.0  ...       66.0       84.0
# 45       87.0   84.0        82.0         90.0  ...       81.0       87.0
# 72       86.0   86.0        92.0         85.0  ...       79.0       86.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(defMid)
# Out:
# 1439

# %%
defMid.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.562752   0.521836         0.455128      0.854465
# Crossing         0.562752  1.000000   0.585699         0.127296      0.548935
# Finishing        0.521836  0.585699   1.000000         0.172517      0.500167
# HeadingAccuracy  0.455128  0.127296   0.172517         1.000000      0.302290
# ShortPassing     0.854465  0.548935   0.500167         0.302290      1.000000
# Volleys          0.518963  0.612779   0.665816         0.175096      0.495578
# Dribbling        0.663375  0.611804   0.608118         0.167702      0.678250
# Curve            0.537599  0.692077   0.583941         0.112000      0.552958
# FKAccuracy       0.490380  0.637787   0.571290         0.103543      0.507383
# LongPassing      0.834873  0.593109   0.528524         0.304022      0.861843
# BallControl      0.833840  0.612468   0.594386         0.281718      0.825089
# ...

# %%
corr=defMid.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
defMid.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# ShortPassing       0.854465
# Reactions          0.852749
# LongPassing        0.834873
# BallControl        0.833840
# Composure          0.810332
# Interceptions      0.805374
# StandingTackle     0.769761
# Vision             0.712175
# Marking            0.693849
# Dribbling          0.663375
# SlidingTackle      0.649926
# ShotPower          0.631359
# LongShots          0.628218
# Positioning        0.571330
# Aggression         0.567295
# Crossing           0.562752
# Stamina            0.538571
# Curve              0.537599
# Finishing          0.521836
# Volleys            0.518963
# FKAccuracy         0.490380
# Penalties          0.472058
# HeadingAccuracy    0.455128
# Strength           0.416275
# Jumping            0.226262
# Agility            0.192046
# GKHandling         0.071193
# Acceleration       0.069777
# GKPositioning      0.058828
# GKDiving           0.058764
# Balance            0.035689
# SprintSpeed        0.032654
# ...

# %% [markdown]
# ### Wingback Analysis (LWB,RWB)

# %%
wingback=players.loc[(players['Position']=='LWB')|(players['Position']=='RWB')].copy()
wingback.head()
# Out:
#      Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 450       80      RWB      68.0       55.0             85.0          75.0
# 465       80      RWB      86.0       28.0             71.0          77.0
# 474       80      LWB      83.0       48.0             54.0          78.0
# 517       80      RWB      82.0       61.0             69.0          78.0
# 581       79      LWB      73.0       74.0             55.0          83.0
#
#      Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  \
# 450     53.0       62.0   44.0        42.0  ...       67.0       71.0
# 465     57.0       76.0   57.0        52.0  ...       54.0       78.0
# 474     49.0       79.0   59.0        42.0  ...       56.0       75.0
# 517     64.0       79.0   42.0        53.0  ...       55.0       82.0
# 581     56.0       76.0   80.0        76.0  ...       68.0       69.0
#
#      Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
wingback.drop(['Position'],axis=1,inplace=True)
wingback.head()
# Out:
#      Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 450       80      68.0       55.0             85.0          75.0     53.0
# 465       80      86.0       28.0             71.0          77.0     57.0
# 474       80      83.0       48.0             54.0          78.0     49.0
# 517       80      82.0       61.0             69.0          78.0     64.0
# 581       79      73.0       74.0             55.0          83.0     56.0
#
#      Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 450       62.0   44.0        42.0         70.0  ...       67.0       71.0
# 465       76.0   57.0        52.0         69.0  ...       54.0       78.0
# 474       79.0   59.0        42.0         70.0  ...       56.0       75.0
# 517       79.0   42.0        53.0         70.0  ...       55.0       82.0
# 581       76.0   80.0        76.0         79.0  ...       68.0       69.0
#
# ...

# %%
len(wingback)
# Out:
# 165

# %%
wingback.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.878275   0.492529         0.652761      0.885130
# Crossing         0.878275  1.000000   0.459142         0.557819      0.801771
# Finishing        0.492529  0.459142   1.000000         0.176920      0.527350
# HeadingAccuracy  0.652761  0.557819   0.176920         1.000000      0.536198
# ShortPassing     0.885130  0.801771   0.527350         0.536198      1.000000
# Volleys          0.529266  0.507685   0.681905         0.306994      0.542433
# Dribbling        0.788264  0.748319   0.585594         0.399405      0.774536
# Curve            0.627961  0.646793   0.503040         0.203678      0.625017
# FKAccuracy       0.501611  0.558826   0.524110         0.175281      0.528866
# LongPassing      0.782028  0.733370   0.527877         0.470517      0.899676
# BallControl      0.876159  0.794270   0.504627         0.537789      0.870298
# ...

# %%
corr=wingback.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
wingback.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# ShortPassing       0.885130
# Crossing           0.878275
# Reactions          0.876291
# BallControl        0.876159
# Marking            0.839429
# Composure          0.814242
# StandingTackle     0.808585
# SlidingTackle      0.800808
# Interceptions      0.797898
# Dribbling          0.788264
# LongPassing        0.782028
# Vision             0.724731
# ShotPower          0.695863
# HeadingAccuracy    0.652761
# Positioning        0.640137
# Curve              0.627961
# Stamina            0.619992
# Penalties          0.568478
# Aggression         0.541645
# Volleys            0.529266
# LongShots          0.528227
# FKAccuracy         0.501611
# Finishing          0.492529
# Strength           0.389224
# SprintSpeed        0.378985
# Acceleration       0.333114
# Agility            0.284836
# GKReflexes         0.204965
# Jumping            0.151731
# GKKicking          0.126136
# Balance            0.104628
# GKDiving           0.066825
# ...

# %% [markdown]
# ### Fullback Analysis (LB,RB)

# %%
fullback=players.loc[(players['Position']=='LB')|(players['Position']=='RB')].copy()
fullback.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 35       88       LB      90.0       70.0             75.0          84.0
# 49       87       LB      87.0       73.0             70.0          84.0
# 64       86       LB      84.0       55.0             76.0          81.0
# 69       86       RB      81.0       46.0             76.0          81.0
# 85       85       LB      81.0       63.0             75.0          82.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 35     54.0       90.0   85.0        67.0  ...       59.0       86.0     71.0
# 49     60.0       80.0   80.0        63.0  ...       59.0       79.0     72.0
# 64     68.0       80.0   78.0        59.0  ...       60.0       82.0     81.0
# 69     51.0       69.0   68.0        58.0  ...       66.0       78.0     88.0
# 85     68.0       79.0   78.0        84.0  ...       80.0       79.0     80.0
#
# ...

# %%
fullback.drop(['Position'],axis=1,inplace=True)
fullback.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 35       88      90.0       70.0             75.0          84.0     54.0
# 49       87      87.0       73.0             70.0          84.0     60.0
# 64       86      84.0       55.0             76.0          81.0     68.0
# 69       86      81.0       46.0             76.0          81.0     51.0
# 85       85      81.0       63.0             75.0          82.0     68.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 35       90.0   85.0        67.0         76.0  ...       59.0       86.0
# 49       80.0   80.0        63.0         74.0  ...       59.0       79.0
# 64       80.0   78.0        59.0         71.0  ...       60.0       82.0
# 69       69.0   68.0        58.0         80.0  ...       66.0       78.0
# 85       79.0   78.0        84.0         80.0  ...       80.0       79.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(fullback)
# Out:
# 2613

# %%
fullback.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.817372   0.492886         0.603968      0.830398
# Crossing         0.817372  1.000000   0.498336         0.393576      0.763023
# Finishing        0.492886  0.498336   1.000000         0.267799      0.523745
# HeadingAccuracy  0.603968  0.393576   0.267799         1.000000      0.494247
# ShortPassing     0.830398  0.763023   0.523745         0.494247      1.000000
# Volleys          0.502961  0.503885   0.680046         0.280164      0.516795
# Dribbling        0.696811  0.698287   0.545688         0.265787      0.627657
# Curve            0.618231  0.676309   0.553935         0.274461      0.620003
# FKAccuracy       0.453960  0.520372   0.520826         0.219420      0.474035
# LongPassing      0.721126  0.689601   0.520760         0.451821      0.828179
# BallControl      0.853611  0.793218   0.543050         0.466226      0.838909
# ...

# %%
corr=fullback.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
fullback.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# StandingTackle     0.860185
# Reactions          0.858713
# BallControl        0.853611
# SlidingTackle      0.853119
# Interceptions      0.847758
# ShortPassing       0.830398
# Crossing           0.817372
# Composure          0.807956
# Marking            0.794465
# LongPassing        0.721126
# Dribbling          0.696811
# ShotPower          0.633593
# Vision             0.629069
# Curve              0.618231
# Aggression         0.608178
# Stamina            0.605004
# HeadingAccuracy    0.603968
# LongShots          0.589006
# Positioning        0.587604
# Volleys            0.502961
# Finishing          0.492886
# FKAccuracy         0.453960
# Penalties          0.438869
# SprintSpeed        0.419632
# Agility            0.393242
# Acceleration       0.362768
# Strength           0.359156
# Jumping            0.312755
# Balance            0.172516
# GKKicking          0.075411
# GKReflexes         0.050275
# GKDiving           0.050072
# ...

# %% [markdown]
# ### Center Back Analysis (RCB,LCB,CB)

# %%
cback=players.loc[(players['Position']=='RCB')|(players['Position']=='LCB')|(players['Position']=='CB')].copy()
cback.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 8        91      RCB      66.0       60.0             91.0          78.0
# 12       90       CB      55.0       42.0             92.0          79.0
# 24       89      LCB      58.0       33.0             83.0          59.0
# 34       88      LCB      64.0       55.0             87.0          81.0
# 39       88      RCB      60.0       38.0             81.0          80.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 8      66.0       63.0   74.0        72.0  ...       75.0       82.0     87.0
# 12     47.0       53.0   49.0        51.0  ...       50.0       82.0     90.0
# 24     45.0       58.0   60.0        31.0  ...       50.0       84.0     93.0
# 34     60.0       68.0   65.0        53.0  ...       68.0       91.0     88.0
# 39     63.0       62.0   61.0        64.0  ...       60.0       81.0     88.0
#
# ...

# %%
cback.drop(['Position'],axis=1,inplace=True)
cback.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 8        91      66.0       60.0             91.0          78.0     66.0
# 12       90      55.0       42.0             92.0          79.0     47.0
# 24       89      58.0       33.0             83.0          59.0     45.0
# 34       88      64.0       55.0             87.0          81.0     60.0
# 39       88      60.0       38.0             81.0          80.0     63.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 8        63.0   74.0        72.0         77.0  ...       75.0       82.0
# 12       53.0   49.0        51.0         70.0  ...       50.0       82.0
# 24       58.0   60.0        31.0         59.0  ...       50.0       84.0
# 34       68.0   65.0        53.0         85.0  ...       68.0       91.0
# 39       62.0   61.0        64.0         80.0  ...       60.0       81.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(cback)
# Out:
# 3088

# %%
cback.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.383717   0.384308         0.832236      0.724332
# Crossing         0.383717  1.000000   0.504082         0.220002      0.532956
# Finishing        0.384308  0.504082   1.000000         0.306577      0.467512
# HeadingAccuracy  0.832236  0.220002   0.306577         1.000000      0.554894
# ShortPassing     0.724332  0.532956   0.467512         0.554894      1.000000
# Volleys          0.314414  0.468589   0.629717         0.224642      0.383034
# Dribbling        0.521379  0.621095   0.523668         0.319080      0.642612
# Curve            0.382323  0.642979   0.551817         0.246736      0.478601
# FKAccuracy       0.335248  0.510788   0.541160         0.234984      0.408369
# LongPassing      0.665571  0.540977   0.505183         0.521493      0.832856
# BallControl      0.703714  0.574976   0.506241         0.507545      0.802632
# ...

# %%
corr=cback.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
cback.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# StandingTackle     0.909005
# Interceptions      0.901862
# Marking            0.872058
# SlidingTackle      0.871751
# Reactions          0.861155
# HeadingAccuracy    0.832236
# Composure          0.799573
# Aggression         0.729125
# ShortPassing       0.724332
# BallControl        0.703714
# LongPassing        0.665571
# Strength           0.536391
# Dribbling          0.521379
# ShotPower          0.496634
# Vision             0.448156
# LongShots          0.414307
# Finishing          0.384308
# Crossing           0.383717
# Curve              0.382323
# FKAccuracy         0.335248
# Penalties          0.333615
# Positioning        0.318637
# Volleys            0.314414
# Stamina            0.294131
# Jumping            0.204343
# Agility            0.167951
# SprintSpeed        0.105622
# GKDiving           0.043864
# GKKicking          0.039521
# GKHandling         0.035654
# GKPositioning      0.028883
# Acceleration       0.017767
# ...

# %% [markdown]
# ### Goal Keeper Analysis (GK)

# %%
keeper=players.loc[(players['Position']=='GK')].copy()
defMid.head()
# Out:
#     Overall Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 14       89      LDM      68.0       65.0             54.0          86.0
# 20       89      CDM      62.0       67.0             68.0          89.0
# 27       88      CDM      52.0       59.0             76.0          85.0
# 45       87      RDM      80.0       73.0             73.0          86.0
# 72       86      CDM      80.0       60.0             60.0          89.0
#
#     Volleys  Dribbling  Curve  FKAccuracy  ...  Penalties  Composure  Marking  \
# 14     56.0       79.0   49.0        49.0  ...       54.0       85.0     90.0
# 20     44.0       80.0   66.0        68.0  ...       60.0       90.0     90.0
# 27     53.0       69.0   59.0        74.0  ...       66.0       84.0     88.0
# 45     85.0       87.0   84.0        82.0  ...       81.0       87.0     66.0
# 72     72.0       86.0   86.0        92.0  ...       79.0       86.0     75.0
#
# ...

# %%
defMid.drop(['Position'],axis=1,inplace=True)
defMid.head()
# Out:
#     Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 14       89      68.0       65.0             54.0          86.0     56.0
# 20       89      62.0       67.0             68.0          89.0     44.0
# 27       88      52.0       59.0             76.0          85.0     53.0
# 45       87      80.0       73.0             73.0          86.0     85.0
# 72       86      80.0       60.0             60.0          89.0     72.0
#
#     Dribbling  Curve  FKAccuracy  LongPassing  ...  Penalties  Composure  \
# 14       79.0   49.0        49.0         81.0  ...       54.0       85.0
# 20       80.0   66.0        68.0         82.0  ...       60.0       90.0
# 27       69.0   59.0        74.0         82.0  ...       66.0       84.0
# 45       87.0   84.0        82.0         90.0  ...       81.0       87.0
# 72       86.0   86.0        92.0         85.0  ...       79.0       86.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
len(defMid)
# Out:
# 1439

# %%
defMid.corr()
# Out:
#                   Overall  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Overall          1.000000  0.562752   0.521836         0.455128      0.854465
# Crossing         0.562752  1.000000   0.585699         0.127296      0.548935
# Finishing        0.521836  0.585699   1.000000         0.172517      0.500167
# HeadingAccuracy  0.455128  0.127296   0.172517         1.000000      0.302290
# ShortPassing     0.854465  0.548935   0.500167         0.302290      1.000000
# Volleys          0.518963  0.612779   0.665816         0.175096      0.495578
# Dribbling        0.663375  0.611804   0.608118         0.167702      0.678250
# Curve            0.537599  0.692077   0.583941         0.112000      0.552958
# FKAccuracy       0.490380  0.637787   0.571290         0.103543      0.507383
# LongPassing      0.834873  0.593109   0.528524         0.304022      0.861843
# BallControl      0.833840  0.612468   0.594386         0.281718      0.825089
# ...

# %%
corr=defMid.corr()
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111) #1x1 grid, 1st subplot
cax=ax.matshow(corr,cmap='coolwarm',vmin=0,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,len(strikers.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(strikers.columns)
ax.set_yticklabels(strikers.columns)
plt.show()

# %%
defMid.corr().iloc[0].sort_values(ascending=False)
# Out:
# Overall            1.000000
# ShortPassing       0.854465
# Reactions          0.852749
# LongPassing        0.834873
# BallControl        0.833840
# Composure          0.810332
# Interceptions      0.805374
# StandingTackle     0.769761
# Vision             0.712175
# Marking            0.693849
# Dribbling          0.663375
# SlidingTackle      0.649926
# ShotPower          0.631359
# LongShots          0.628218
# Positioning        0.571330
# Aggression         0.567295
# Crossing           0.562752
# Stamina            0.538571
# Curve              0.537599
# Finishing          0.521836
# Volleys            0.518963
# FKAccuracy         0.490380
# Penalties          0.472058
# HeadingAccuracy    0.455128
# Strength           0.416275
# Jumping            0.226262
# Agility            0.192046
# GKHandling         0.071193
# Acceleration       0.069777
# GKPositioning      0.058828
# GKDiving           0.058764
# Balance            0.035689
# SprintSpeed        0.032654
# ...
